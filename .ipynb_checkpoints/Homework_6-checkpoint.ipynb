# %% [markdown]
# # Homework 6 (more of a tutorial, really)

# %% [markdown]
# As I was browsing through Kaggle the other day, I came upon a brand new dataset from the University of Puerto Rico, which contains images of bees entering their hive.  The task is to determine automatically which bees are carrying pollen.  Your job will be to develop a convolutional neural network that performs this task.

# %% [markdown]
# ## 1. Load Data (0 pts)

# %% [markdown]
# First, we need to load the bee data, which is included along with this homework.  Fortunately, the authors of the Kaggle dataset provided a nice set of files which will do this for us, which I have reproduced below

# %%
import glob, os 
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path="images/"
imlist= glob.glob(os.path.join(path, '*.jpg'))

# %%
def dataset(file_list,size=(300,180),flattened=False):
    data = []
    for i, file in enumerate(file_list):
        image = io.imread(file)
        image = transform.resize(image, size, mode='constant')
        if flattened:
            image = image.flatten()

        data.append(image)

    #labels = [1 if f.split("/")[-1][0] == 'P' else 0 for f in file_list]
    #I had to do this in order to get the dataset to properly split into 
    #np and p classes. your split for labels was always the i in image
    #so everything would be in the 0 class...
    #my guess is os differences, as I am using windows on my desktop so 
    #I can use my gpu. and this wasn't happening when I was using a 
    #ubuntu virtual machine on my laptop. 
    labels = [1 if f.split("\\")[1][0] =='P' else 0 for f in file_list]
    return np.array(data), np.array(labels)

# %%
# Load the dataset (may take a few seconds)
X,y=dataset(imlist)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)
# Out:
# c:\users\josh\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
# X has the following structure: X[imageid, y,x,channel]
print('X: ',X.shape)  # data
print('y: ',y.shape)  # target
print('Class 0: ',sum(y==0))
print('Class 1: ',sum(y==1))
print('Total  : ',len(y))
# Out:
# X:  (714, 300, 180, 3)
# y:  (714,)
# Class 0:  345
# Class 1:  369
# Total  :  714

# %% [markdown]
# We can plot a couple of the images below.  If you check out a couple of these, you will see that the visible difference when bees carry pollen is the presence of large fluffy balls of pollen on their back legs.

# %%
fig, axes = plt.subplots(1,2)
k=0
plt.sca(axes[0])
plt.imshow(X[k])
plt.title('img {} - class {}'.format(k, y[k]))

k=401
plt.sca(axes[1])
plt.imshow(X[k])
plt.title('img {} - class {}'.format(k, y[k]));

# %% [markdown]
# ## 2. A convolutional network architecture for bee classification (40 pts)
#
# **Implement a 2D convolutional neural network using Keras.  You are free to choose whatever network architecture you like.**
#
# You can find all the relevant syntax for implementing such a network [here](https://github.com/keras-team/keras/blob/master/examples/mnist_cnn.py), the Keras convnet example for MNIST.
#
# *(For the sake of comparison, I will share the one that I used:*
#
# Layer 1: 5x5 convolution layer with 24 kernels and a relu activation function
#
# Layer 2: 4x4 Max-pooling layer
#
# Layer 3: 5x5 convolution layer with 24 kernels and a relu activation function
#
# Layer 4: 4x4 Max-pooling layer
#
# Layer 5: 5x5 convolution layer with 24 kernels and a relu activation function
#
# Layer 6: 4x4 Max-pooling layer
#
# Layer 7: Flattening layer
#
# Layer 8: Dropout layer with 0.2 dropout probability
#
# Layer 9: 1 node sigmoid layer

# %%
import keras
import keras.models as km
import keras.layers as kl

import numpy as np

input_shape = ((300,180,3))

model = km.Sequential()
#I started with a cnn similar to yours and kept messing with it.
#This one is the best I've gotten it. 
#It was kind of fun to see what would add or subtract from the accuracy. 
model.add(kl.Conv2D(32,kernel_size = (4,4),activation='relu',input_shape=input_shape))
model.add(kl.MaxPooling2D(pool_size=(3,3)))
model.add(kl.Conv2D(32,kernel_size =(4,4),activation='relu',input_shape=input_shape))
model.add(kl.MaxPooling2D(pool_size=(2,2)))
model.add(kl.Conv2D(32,kernel_size =(4,4),activation='relu',input_shape=input_shape))
model.add(kl.MaxPooling2D(pool_size=(5,5)))
model.add(kl.Flatten())
model.add(kl.Dropout(0.2))
model.add(kl.Dense(1, activation='sigmoid'))

# %% [markdown]
# ## 3. Fitting the CNN to data (20 pts)
#
# Compile your model, using a binary crossentropy loss function and an optimizer of your choosing (RMSprop worked well for me).  Select a batch size and number of epochs, and fit your model to the training data, while also keeping track of the test set accuracy.
#
# **Plot the training and test accuracy of your model at each epoch.  Comment on whether you think the model is being overfit.**

# %%
model.compile(loss=keras.losses.binary_crossentropy,
              optimizer=keras.optimizers.RMSprop(),
              metrics=['accuracy'])

batch_size = 20                       
epochs= 35                        
history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_test,y_test))


plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
# Out:
# Train on 571 samples, validate on 143 samples
# Epoch 1/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.6225 - acc: 0.6532 - val_loss: 0.5985 - val_acc: 0.6573
# Epoch 2/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.4561 - acc: 0.7968 - val_loss: 0.4203 - val_acc: 0.8462
# Epoch 3/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.3693 - acc: 0.8336 - val_loss: 0.4253 - val_acc: 0.8392
# Epoch 4/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.3565 - acc: 0.8511 - val_loss: 0.3224 - val_acc: 0.8811
# Epoch 5/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.3253 - acc: 0.8476 - val_loss: 0.3431 - val_acc: 0.8531
# Epoch 6/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.2786 - acc: 0.8862 - val_loss: 0.3271 - val_acc: 0.8671
# Epoch 7/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.2838 - acc: 0.8827 - val_loss: 0.2979 - val_acc: 0.8741
# Epoch 8/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.2355 - acc: 0.9002 - val_loss: 0.3004 - val_acc: 0.8741
# Epoch 9/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.2207 - acc: 0.9194 - val_loss: 0.3750 - val_acc: 0.8252
# Epoch 10/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.2318 - acc: 0.8984 - val_loss: 0.2915 - val_acc: 0.8951
# Epoch 11/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.2071 - acc: 0.9177 - val_loss: 0.2657 - val_acc: 0.9091
# Epoch 12/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.1922 - acc: 0.9177 - val_loss: 0.3321 - val_acc: 0.8881
# Epoch 13/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.1824 - acc: 0.9212 - val_loss: 0.2666 - val_acc: 0.8881
# Epoch 14/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.1642 - acc: 0.9422 - val_loss: 0.2915 - val_acc: 0.8951
# Epoch 15/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.1463 - acc: 0.9475 - val_loss: 0.1993 - val_acc: 0.9301
# Epoch 16/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.1562 - acc: 0.9387 - val_loss: 0.3057 - val_acc: 0.8741
# Epoch 17/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.1470 - acc: 0.9405 - val_loss: 0.2338 - val_acc: 0.9161
# Epoch 18/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.1155 - acc: 0.9527 - val_loss: 0.2586 - val_acc: 0.9091
# Epoch 19/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.1184 - acc: 0.9475 - val_loss: 0.2150 - val_acc: 0.9161
# Epoch 20/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.1228 - acc: 0.9457 - val_loss: 0.3309 - val_acc: 0.8671
# Epoch 21/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.1157 - acc: 0.9527 - val_loss: 0.6154 - val_acc: 0.8322
# Epoch 22/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.1167 - acc: 0.9597 - val_loss: 0.1801 - val_acc: 0.9371
# Epoch 23/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.0953 - acc: 0.9615 - val_loss: 0.1993 - val_acc: 0.9231
# Epoch 24/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.0847 - acc: 0.9720 - val_loss: 0.2224 - val_acc: 0.9301
# Epoch 25/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.0869 - acc: 0.9615 - val_loss: 0.4186 - val_acc: 0.9161
# Epoch 26/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.0685 - acc: 0.9702 - val_loss: 0.2793 - val_acc: 0.9161
# Epoch 27/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.0681 - acc: 0.9720 - val_loss: 0.4973 - val_acc: 0.8881
# Epoch 28/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.0874 - acc: 0.9720 - val_loss: 0.2238 - val_acc: 0.9301
# Epoch 29/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.0744 - acc: 0.9737 - val_loss: 0.2286 - val_acc: 0.9301
# Epoch 30/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.0730 - acc: 0.9737 - val_loss: 0.1856 - val_acc: 0.9301
# Epoch 31/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.0748 - acc: 0.9720 - val_loss: 0.4059 - val_acc: 0.9091
# Epoch 32/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.0675 - acc: 0.9790 - val_loss: 0.2353 - val_acc: 0.9441
# Epoch 33/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.0682 - acc: 0.9702 - val_loss: 0.2921 - val_acc: 0.9161
# Epoch 34/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.0506 - acc: 0.9860 - val_loss: 0.2435 - val_acc: 0.9301
# Epoch 35/35
# 571/571 [==============================] - 2s 4ms/step - loss: 0.0629 - acc: 0.9790 - val_loss: 0.2426 - val_acc: 0.9231

# %% [markdown]
# ### I think that my model is probably being overfit a bit. After about 10 epochs the test set doesn't quite keep pace with the training set. Which is a sign of overfitting. But it is not that far behind.
#
#
#
# ## 4. Model evaluation (20 pts)
#
# Now that you have a trained model, make a prediction for the test set (model.predict is a useful function for this).  **Compute and display a confusion matrix.  Select and display an example from the test set of a true positive, a true negative, a false positive, and a false negative.  Speculate on the reasons behind misclassification for images that your model predicted incorrectly**.

# %%
predictions = model.predict(X_test)
from sklearn.metrics import confusion_matrix
classes = [1 if pred>.5 else 0 for pred in predictions]
confusion = confusion_matrix(classes,y_test)
#Grabbing the first example of each classification. 
for i in range(0, len(predictions)):
    if(y_test[i] == 1 and classes[i] == 1):
        truePositive = i
    if(y_test[i] == 0 and classes[i] == 0):
        trueNegative = i
    if(y_test[i] ==1 and classes[i] == 0):
        falseNegative = i
    if(y_test[i] == 0 and classes[i] == 1):
        falsePositive = i
    try:
        if(truePositive is not None and trueNegative is not None and falseNegative is not None and falsePositive is not None ):
            break
    except NameError:
        continue
print(confusion)
print("In this case a positive is a bee that is carrying pollen, a negative is one that is not.")
fig, axes = plt.subplots(2,2)
plt.sca(axes[0,0])
plt.imshow(X_test[truePositive])
title = "True Positive at index:" +str(truePositive)
plt.title(title)
plt.sca(axes[0,1])
plt.imshow(X_test[trueNegative])
title ="True Negative at index: " +str(trueNegative)
plt.title(title)
plt.sca(axes[1,0])
plt.imshow(X_test[falsePositive])
title = "False Positive at index: "+ str(falsePositive)
plt.title(title)
plt.sca(axes[1,1])
plt.imshow(X_test[falseNegative])
title = "False Negative at index: "+str(falseNegative)
plt.title(title)
plt.tight_layout()
total = confusion.sum()
acc = confusion[0,0] + confusion[1,1]
acc /=total
acc *=100
print("Accuracy: " , str(acc) , "%")
# Out:
# [[62  5]
#  [ 6 70]]
# In this case a positive is a bee that is carrying pollen, a negative is one that is not.
# Accuracy:  92.3076923076923 %

# %%
##In the false positive the picture is cutting off the bees head and you can see what
#is a similar color to pollen up by its front legs and head. I can see that being classified as pollen by the cnn.
#As for the false negative, I'm having a bit of a harder time seeing why it would have misclassified this bee.
#Perhaps because of the pollen on its right leg is sort of hidden and harder to see.
