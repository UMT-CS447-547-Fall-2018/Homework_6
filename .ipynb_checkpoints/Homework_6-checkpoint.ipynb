# %% [markdown]
# # Homework 6 (more of a tutorial, really)

# %% [markdown]
# As I was browsing through Kaggle the other day, I came upon a brand new dataset from the University of Puerto Rico, which contains images of bees entering their hive.  The task is to determine automatically which bees are carrying pollen.  Your job will be to develop a convolutional neural network that performs this task.

# %% [markdown]
# ## 1. Load Data (0 pts)

# %% [markdown]
# First, we need to load the bee data, which is included along with this homework.  Fortunately, the authors of the Kaggle dataset provided a nice set of files which will do this for us, which I have reproduced below

# %%
import glob, os 
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path="images/"
imlist= glob.glob(os.path.join(path, '*.jpg'))

# %%
def dataset(file_list,size=(300,180),flattened=False):
    data = []
    for i, file in enumerate(file_list):
        image = io.imread(file)
        image = transform.resize(image, size, mode='constant')
        if flattened:
            image = image.flatten()

        data.append(image)

    #labels = [1 if f.split("/")[-1][0] == 'P' else 0 for f in file_list]
    #I had to do this in order to get the dataset to properly split into 
    #np and p classes. your split for labels was always the i in image
    #so everything would be in the 0 class...
    #my guess is os differences, as I am using windows on my desktop so 
    #I can use my gpu. and this wasn't happening when I was using a 
    #ubuntu virtual machine on my laptop. 
    labels = [1 if f.split("\\")[1][0] =='P' else 0 for f in file_list]
    return np.array(data), np.array(labels)

# %%
# Load the dataset (may take a few seconds)
X,y=dataset(imlist)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
# X has the following structure: X[imageid, y,x,channel]
print('X: ',X.shape)  # data
print('y: ',y.shape)  # target
print('Class 0: ',sum(y==0))
print('Class 1: ',sum(y==1))
print('Total  : ',len(y))
# Out:
# X:  (714, 300, 180, 3)
# y:  (714,)
# Class 0:  345
# Class 1:  369
# Total  :  714

# %% [markdown]
# We can plot a couple of the images below.  If you check out a couple of these, you will see that the visible difference when bees carry pollen is the presence of large fluffy balls of pollen on their back legs.

# %%
fig, axes = plt.subplots(1,2)
k=0
plt.sca(axes[0])
plt.imshow(X[k])
plt.title('img {} - class {}'.format(k, y[k]))

k=401
plt.sca(axes[1])
plt.imshow(X[k])
plt.title('img {} - class {}'.format(k, y[k]));

# %% [markdown]
# ## 2. A convolutional network architecture for bee classification (40 pts)
#
# **Implement a 2D convolutional neural network using Keras.  You are free to choose whatever network architecture you like.**
#
# You can find all the relevant syntax for implementing such a network [here](https://github.com/keras-team/keras/blob/master/examples/mnist_cnn.py), the Keras convnet example for MNIST.
#
# *(For the sake of comparison, I will share the one that I used:*
#
# Layer 1: 5x5 convolution layer with 24 kernels and a relu activation function
#
# Layer 2: 4x4 Max-pooling layer
#
# Layer 3: 5x5 convolution layer with 24 kernels and a relu activation function
#
# Layer 4: 4x4 Max-pooling layer
#
# Layer 5: 5x5 convolution layer with 24 kernels and a relu activation function
#
# Layer 6: 4x4 Max-pooling layer
#
# Layer 7: Flattening layer
#
# Layer 8: Dropout layer with 0.2 dropout probability
#
# Layer 9: 1 node sigmoid layer

# %%
import keras
import keras.models as km
import keras.layers as kl

import numpy as np

input_shape = ((300,180,3))

model = km.Sequential()
#! Add layers to your convolutional neural network   
model.add(kl.Conv2D(32,kernel_size = (4,4),activation='relu',input_shape=input_shape))
model.add(kl.MaxPooling2D(pool_size=(2,2)))
model.add(kl.Conv2D(32,kernel_size =(4,4),activation='relu',input_shape=input_shape))
model.add(kl.MaxPooling2D(pool_size=(2,2)))
model.add(kl.Conv2D(32,kernel_size =(4,4),activation='relu',input_shape=input_shape))
model.add(kl.MaxPooling2D(pool_size=(2,2)))
model.add(kl.Flatten())
model.add(kl.Dropout(0.2))
model.add(kl.Dense(1, activation='sigmoid'))

# %% [markdown]
# ## 3. Fitting the CNN to data (20 pts)
#
# Compile your model, using a binary crossentropy loss function and an optimizer of your choosing (RMSprop worked well for me).  Select a batch size and number of epochs, and fit your model to the training data, while also keeping track of the test set accuracy.
#
# **Plot the training and test accuracy of your model at each epoch.  Comment on whether you think the model is being overfit.**

# %%
model.compile(loss=keras.losses.binary_crossentropy,
              optimizer=keras.optimizers.RMSprop(),
              metrics=['accuracy'])

batch_size = 20                       
epochs= 35                        
history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_test,y_test))

#! Plot test and training accuracy (note that the history.history object is a dictionary containing relevant info)
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
# Out:
# Train on 571 samples, validate on 143 samples
# Epoch 1/35
# 571/571 [==============================] - 4s 6ms/step - loss: 0.6619 - acc: 0.6200 - val_loss: 0.6581 - val_acc: 0.6084
# Epoch 2/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.4901 - acc: 0.7986 - val_loss: 0.4831 - val_acc: 0.8601
# Epoch 3/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.4268 - acc: 0.8424 - val_loss: 0.4737 - val_acc: 0.8182
# Epoch 4/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.3661 - acc: 0.8406 - val_loss: 0.6667 - val_acc: 0.6643
# Epoch 5/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.3373 - acc: 0.8581 - val_loss: 0.4077 - val_acc: 0.8601
# Epoch 6/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.2918 - acc: 0.8651 - val_loss: 0.3555 - val_acc: 0.8741
# Epoch 7/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.2566 - acc: 0.8932 - val_loss: 0.3797 - val_acc: 0.8182
# Epoch 8/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.2168 - acc: 0.9142 - val_loss: 0.3611 - val_acc: 0.8322
# Epoch 9/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1965 - acc: 0.9299 - val_loss: 0.3174 - val_acc: 0.8671
# Epoch 10/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1623 - acc: 0.9440 - val_loss: 0.3425 - val_acc: 0.8671
# Epoch 11/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1245 - acc: 0.9545 - val_loss: 0.3226 - val_acc: 0.8951
# Epoch 12/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0991 - acc: 0.9650 - val_loss: 0.3364 - val_acc: 0.8811
# Epoch 13/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0996 - acc: 0.9615 - val_loss: 0.3536 - val_acc: 0.8671
# Epoch 14/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1061 - acc: 0.9650 - val_loss: 0.3961 - val_acc: 0.8951
# Epoch 15/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0577 - acc: 0.9807 - val_loss: 0.5621 - val_acc: 0.8531
# Epoch 16/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0490 - acc: 0.9807 - val_loss: 0.4952 - val_acc: 0.8881
# Epoch 17/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0321 - acc: 0.9912 - val_loss: 0.6876 - val_acc: 0.8462
# Epoch 18/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0560 - acc: 0.9755 - val_loss: 0.4309 - val_acc: 0.8531
# Epoch 19/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0158 - acc: 0.9930 - val_loss: 0.6080 - val_acc: 0.8671
# Epoch 20/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0708 - acc: 0.9772 - val_loss: 0.6240 - val_acc: 0.8741
# Epoch 21/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0254 - acc: 0.9912 - val_loss: 0.6341 - val_acc: 0.8671
# Epoch 22/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0740 - acc: 0.9755 - val_loss: 0.6652 - val_acc: 0.8601
# Epoch 23/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0064 - acc: 1.0000 - val_loss: 0.7927 - val_acc: 0.8531
# Epoch 24/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0028 - acc: 1.0000 - val_loss: 1.0248 - val_acc: 0.8462
# Epoch 25/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0156 - acc: 0.9965 - val_loss: 0.7972 - val_acc: 0.8392
# Epoch 26/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0369 - acc: 0.9895 - val_loss: 0.7323 - val_acc: 0.8462
# Epoch 27/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0041 - acc: 1.0000 - val_loss: 0.9171 - val_acc: 0.8531
# Epoch 28/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0199 - acc: 0.9947 - val_loss: 0.9396 - val_acc: 0.8392
# Epoch 29/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0145 - acc: 0.9930 - val_loss: 0.8981 - val_acc: 0.8531
# Epoch 30/35
# 571/571 [==============================] - 3s 5ms/step - loss: 1.6764e-04 - acc: 1.0000 - val_loss: 0.9767 - val_acc: 0.8671
# Epoch 31/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0237 - acc: 0.9930 - val_loss: 0.9313 - val_acc: 0.8671
# Epoch 32/35
# 571/571 [==============================] - 3s 5ms/step - loss: 8.1823e-04 - acc: 1.0000 - val_loss: 0.7786 - val_acc: 0.8671
# Epoch 33/35
# 571/571 [==============================] - 3s 5ms/step - loss: 3.4654e-04 - acc: 1.0000 - val_loss: 0.7377 - val_acc: 0.8881
# Epoch 34/35
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0241 - acc: 0.9930 - val_loss: 1.0272 - val_acc: 0.8601
# Epoch 35/35
# 571/571 [==============================] - 3s 5ms/step - loss: 2.3147e-04 - acc: 1.0000 - val_loss: 0.9395 - val_acc: 0.8741

# %% [markdown]
# ## 4. Model evaluation (20 pts)
#
# Now that you have a trained model, make a prediction for the test set (model.predict is a useful function for this).  **Compute and display a confusion matrix.  Select and display an example from the test set of a true positive, a true negative, a false positive, and a false negative.  Speculate on the reasons behind misclassification for images that your model predicted incorrectly**.

# %%
#! See above
predictions = model.predict(X_test)
from sklearn.metrics import confusion_matrix
classes = [1 if pred>.5 else 0 for pred in predictions]
confusion = confusion_matrix(classes,y_test)
print(confusion)
plt.imshow(X_test[0])
# Out:
# [[57  7]
#  [11 68]]
