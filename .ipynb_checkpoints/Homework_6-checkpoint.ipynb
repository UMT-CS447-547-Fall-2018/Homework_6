# %% [markdown]
# # Homework 6 (more of a tutorial, really)

# %% [markdown]
# As I was browsing through Kaggle the other day, I came upon a brand new dataset from the University of Puerto Rico, which contains images of bees entering their hive.  The task is to determine automatically which bees are carrying pollen.  Your job will be to develop a convolutional neural network that performs this task.

# %% [markdown]
# ## 1. Load Data (0 pts)

# %% [markdown]
# First, we need to load the bee data, which is included along with this homework.  Fortunately, the authors of the Kaggle dataset provided a nice set of files which will do this for us, which I have reproduced below

# %%
import glob, os 
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\ProgramData\Anaconda3\python.exe

# %%
path="images/"
imlist= glob.glob(os.path.join(path, '*.jpg'))

# %%
def dataset(file_list,size=(300,180),flattened=False):
    data = []
    for i, file in enumerate(file_list):
        image = io.imread(file)
        image = transform.resize(image, size, mode='constant')
        if flattened:
            image = image.flatten()

        data.append(image)

    labels = [1 if f.split("/") == 'P' else 0 for f in file_list]

    return np.array(data), np.array(labels)

# %%
# Load the dataset (may take a few seconds)
X,y=dataset(imlist)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
import glob, os 
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

path="images/"
imlist= glob.glob(os.path.join(path, '*.jpg'))

def dataset(file_list,size=(300,180),flattened=False):
    data = []
    for i, file in enumerate(file_list):
        image = io.imread(file)
        image = transform.resize(image, size, mode='constant')
        if flattened:
            image = image.flatten()

        data.append(image)

    labels = [1 if f.split("\\")[-1][0] == 'P' else 0 for f in file_list]

    return np.array(data), np.array(labels)

# Load the dataset (may take a few seconds)
X,y=dataset(imlist)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# X has the following structure: X[imageid, y,x,channel]
print('X: ',X.shape)  # data
print('y: ',y.shape)  # target
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
print('Class 0: ',sum(y==0))
print('Class 1: ',sum(y==1))
print('Total  : ',len(y))
# Out:
# X:  (714, 300, 180, 3)
# y:  (714,)
# (571, 300, 180, 3)
# (143, 300, 180, 3)
# (571,)
# (143,)
# Class 0:  345
# Class 1:  369
# Total  :  714

# %% [markdown]
# We can plot a couple of the images below.  If you check out a couple of these, you will see that the visible difference when bees carry pollen is the presence of large fluffy balls of pollen on their back legs.

# %%
fig, axes = plt.subplots(1,2)
k=12
plt.sca(axes[0])
plt.imshow(X[k])
plt.title('img {} - class {}'.format(k, y[k]))

k=399
plt.sca(axes[1])
plt.imshow(X[k])
plt.title('img {} - class {}'.format(k, y[k]));

# %% [markdown]
# ## 2. A convolutional network architecture for bee classification (40 pts)
#
# **Implement a 2D convolutional neural network using Keras.  You are free to choose whatever network architecture you like.**
#
# You can find all the relevant syntax for implementing such a network [here](https://github.com/keras-team/keras/blob/master/examples/mnist_cnn.py), the Keras convnet example for MNIST.
#
# *(For the sake of comparison, I will share the one that I used:*
#
# Layer 1: 5x5 convolution layer with 24 kernels and a relu activation function
#
# Layer 2: 4x4 Max-pooling layer
#
# Layer 3: 5x5 convolution layer with 24 kernels and a relu activation function
#
# Layer 4: 4x4 Max-pooling layer
#
# Layer 5: 5x5 convolution layer with 24 kernels and a relu activation function
#
# Layer 6: 4x4 Max-pooling layer
#
# Layer 7: Flattening layer
#
# Layer 8: Dropout layer with 0.2 dropout probability
#
# Layer 9: 1 node sigmoid layer

# %%
import glob, os 
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

import keras
import keras.models as km
import keras.layers as kl
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dense, Dropout, Flatten
import numpy as np

path="images/"
imlist= glob.glob(os.path.join(path, '*.jpg'))

def dataset(file_list,size=(300,180),flattened=False):
    data = []
    for i, file in enumerate(file_list):
        image = io.imread(file)
        image = transform.resize(image, size, mode='constant')
        if flattened:
            image = image.flatten()

        data.append(image)

    labels = [1 if f.split("\\")[-1][0] == 'P' else 0 for f in file_list]

    return np.array(data), np.array(labels)

X,y=dataset(imlist)

print('X: ',X.shape)  # data
print('y: ',y.shape)  # target

print('Class 0: ',sum(y==0))
print('Class 1: ',sum(y==1))
print('Total  : ',len(y))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)

input_shape = ((300,180,3))

model = km.Sequential()
model.add(Conv2D(32, kernel_size=(5, 5), strides=(1, 1), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(4, 4)))
model.add(Conv2D(64, kernel_size=(5, 5), strides=(1, 1), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(4, 4)))       
model.add(Flatten())
model.add(Dense(1000, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# X:  (714, 300, 180, 3)
# y:  (714,)
# Class 0:  345
# Class 1:  369
# Total  :  714

# %% [markdown]
# ## 3. Fitting the CNN to data (20 pts)
#
# Compile your model, using a binary crossentropy loss function and an optimizer of your choosing (RMSprop worked well for me).  Select a batch size and number of epochs, and fit your model to the training data, while also keeping track of the test set accuracy.
#
# **Plot the training and test accuracy of your model at each epoch.  Comment on whether you think the model is being overfit.**

# %%
import glob, os 
from skimage import io, transform
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

import keras
import keras.models as km
import keras.layers as kl
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dense, Dropout, Flatten
import numpy as np

path="images/"
imlist= glob.glob(os.path.join(path, '*.jpg'))

def dataset(file_list,size=(300,180),flattened=False):
    data = []
    for i, file in enumerate(file_list):
        image = io.imread(file)
        image = transform.resize(image, size, mode='constant')
        if flattened:
            image = image.flatten()

        data.append(image)

    labels = [1 if f.split("\\")[-1][0] == 'P' else 0 for f in file_list]

    return np.array(data), np.array(labels)

X,y=dataset(imlist)

print('X: ',X.shape)  # data
print('y: ',y.shape)  # target

print('Class 0: ',sum(y==0))
print('Class 1: ',sum(y==1))
print('Total  : ',len(y))


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)

input_shape = ((300,180,3))

model = km.Sequential()
model.add(Conv2D(32, kernel_size=(5, 5), strides=(1, 1), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(4, 4)))
model.add(Conv2D(64, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(4, 4)))   
model.add(Conv2D(64, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(4, 4))) 
#model.add(Dense(102, activation='relu'))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))   

model.compile(loss=keras.losses.binary_crossentropy,                #! Specify a loss function
              optimizer='rmsprop',           #! Specify an optimizer
              metrics=['accuracy'])

batch_size = 102                     #! Specify a batch size
epochs= 10                          #! Specify an epoch  
history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_test,y_test))



score = model.evaluate(X_test, y_test, batch_size=102)
# Out:
# X:  (714, 300, 180, 3)
# y:  (714,)
# Class 0:  345
# Class 1:  369
# Total  :  714
# Train on 571 samples, validate on 143 samples
# Epoch 1/10
# 571/571 [==============================] - 71s 124ms/step - loss: 0.8166 - acc: 0.5061 - val_loss: 0.6881 - val_acc: 0.7413
# Epoch 2/10
# 571/571 [==============================] - 72s 125ms/step - loss: 0.6849 - acc: 0.5814 - val_loss: 0.6670 - val_acc: 0.7762
# Epoch 3/10
# 571/571 [==============================] - 79s 138ms/step - loss: 0.6570 - acc: 0.6392 - val_loss: 0.6213 - val_acc: 0.6783
# Epoch 4/10
# 571/571 [==============================] - 70s 123ms/step - loss: 0.6183 - acc: 0.6865 - val_loss: 0.5748 - val_acc: 0.8182
# Epoch 5/10
# 571/571 [==============================] - 72s 125ms/step - loss: 0.5529 - acc: 0.7618 - val_loss: 0.6421 - val_acc: 0.5524
# Epoch 6/10
# 571/571 [==============================] - 73s 127ms/step - loss: 0.5725 - acc: 0.7058 - val_loss: 0.4816 - val_acc: 0.8112
# Epoch 7/10
# 571/571 [==============================] - 75s 131ms/step - loss: 0.4924 - acc: 0.7793 - val_loss: 0.6095 - val_acc: 0.5944
# Epoch 8/10
# 571/571 [==============================] - 74s 129ms/step - loss: 0.5019 - acc: 0.7513 - val_loss: 0.4051 - val_acc: 0.8531
# Epoch 9/10
# 571/571 [==============================] - 82s 143ms/step - loss: 0.4437 - acc: 0.8091 - val_loss: 0.5089 - val_acc: 0.7273
# Epoch 10/10
# 571/571 [==============================] - 83s 145ms/step - loss: 0.4191 - acc: 0.8214 - val_loss: 0.3552 - val_acc: 0.8531
# 143/143 [==============================] - 8s 54ms/step

# %% [markdown]
# ## 4. Model evaluation (20 pts)
#
# Now that you have a trained model, make a prediction for the test set (model.predict is a useful function for this).  **Compute and display a confusion matrix.  Select and display an example from the test set of a true positive, a true negative, a false positive, and a false negative.  Speculate on the reasons behind misclassification for images that your model predicted incorrectly**.

# %%
from sklearn.metrics import confusion_matrix

pred = model.predict_classes(X_test, batch_size = 102, verbose =0 )

fn = 0
tn = 0
fp = 0
tp = 0
kfn = 0
ktn = 0
kfp = 0
ktp = 0

count = 0
for item in pred:
    if(item == 0):
        if(y_test[count] == 0):
            tn += 1
            ktn = count
        else:
            fn += 1
            kfn = count
    elif(item == 1):
        if(y_test[count] == 1):
            tp += 1
            ktp = count
        else:
            fp += 1
            kfp = count
    count += 1
    
conmat = confusion_matrix(y_test, pred)
print("  0  1 ")
print(conmat)
print()
print("True negative: ")
print(tn)
print("False negative")
print(fn)
print("False positive")
print(fp)
print("True positive")
print(tp)

fig, axes = plt.subplots(1,2)
k=ktp
plt.sca(axes[0])
plt.imshow(X_test[k])
plt.title("True positive")

k=ktn
plt.sca(axes[1])
plt.imshow(X_test[k])
plt.title("True negative");


plt.plot(history.history['acc'])

plt.plot(history.history['val_acc'])
plt.show()

#I don't think my model is being overfit.  I wasn't able to make my CNN more accurate, partially because of the 
#huge computation time on my laptop.  Each run took about twenty minutes.
# Out:
#   0  1
# [[52 16]
#  [ 5 70]]
#
# True negative:
# 52
# False negative
# 5
# False positive
# 16
# True positive
# 70

# %%
fig, axes = plt.subplots(1,2)
k=kfp
plt.sca(axes[0])
plt.imshow(X_test[k])
plt.title("False positive")

k=kfn
plt.sca(axes[1])
plt.imshow(X_test[k])
plt.title("False negative");
